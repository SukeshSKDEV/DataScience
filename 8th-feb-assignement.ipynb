# %%
# Q.1 What is Abstraction in OOps? Explain with an example.
Abstraction means exposing only "relevant" data in a class interface, hiding private attributes and methods 
from users.
We hide data by adding by adding double underscore (__) as a prefix to the attribute, which you want to hide.

In the following example, I have created a class Employee whose salary has been hide by abstraction (double underscore).
The salary is only visible using method display_salary. There is no direct access to salary attribute.

class Employee:
    def __init__(self,first,last,age,salary):
        self.first=first
        self.last=last
        self.age=age
        self.__salary=salary
        
    def display_salary(self):
        return f"The salary of {self.first} {self.last} is {self.__salary}."

vinay=Employee('Vinay','Sharma',26,50000)
vinay.display_salary()

# %%
Q2. Differentiate between Abstraction and Encapsulation.

->         Abstraction                                                      Encapsulation

1. Abstraction means exposing only "relevant"               1. The grouping of public and private attributes
   data in a class interface, hiding private                   and methods into programmatic class, making
   attributes and methods                                      abstraction possible.
   from users
    
2. It highlights what is the work of object                 2. It focuses on the inner details of  how the
   rather than how the object works.                            object works.
    
3. It hides the unnecessary details on the                  3. It also hides the details but on the 
   design level.                                               implementation level.

4. It deals with ideas rather than events.                  4. The idea is to protect the data from outside
                                                                world.


ex. In the example below, Patients class is an example of Encapsulation which is enclosing all the methods 
and attributes, while methods like methods like display_age and display_issue is an example of abstraction 
which is hiding the attributes age and disease.

class Patients:
    def __init__(self,first,last,age,disease):
        self.first=first
        self.last=last
        self.__age=age
        self.__disease=disease
    
    def display_age(self):
        return f"The age of {self.first} {self.last} is {self.__age}"
    
    def display_issue(self):
        return f"Issue with {self.first} {self.last} is {self.__disease}"

karan=Patients('Karan','Ahuja',28,'Fever')
karan.display_age()
karan.display_issue()

# %%
Q.3
 # What is abc module in python ?
 The 'abc' module in Python library provides the infrastructure for defining custom abstract base classes.
 
 Abstract base classes provide a blueprint for concrete classes. They don’t contain implementation. Instead, they provide an interface
 and make sure that derived concrete classes are properly implemented.
 * Abstract base classes cannot be instantiated. Instead, they are inherited and extended by the concrete subclasses. 
 * Subclasses derived from a specific abstract base class must implement the methods and properties provided in that abstract base class. 
   Otherwise, an error is raised during the object instantiation.

 # Why is it used ?
 For larger projects, it is impossible to remember the class details, and also the reusability of code can increase the bug. Therefore, 
 abstract base class a crucial role in these projects.

# %%
Q.4
How can we achieve data abstraction ?
Data Abstraction in Python can be achieved through creating abstract classes and inheriting them later. 
We use the abc module of Python, which provides the base and necessary tools for defining Abstract Base Classes (ABC).

ex.: In the following example, we created abstract method speak in the Parent Animal Class using abc module. 
     Then we implemented this speak method in the child class Dog and Cat.
     

from abc import ABC, abstractmethod
class Animal(ABC):
    @abstractmethod
    def speak(self):
        pass
class Dog(Animal):
    def speak(self):
        return "woof"
class Cat(Animal):
    def speak(self):
        return "meow"

d=Dog()
d.speak()
c=Cat()
c.speak()

# %%
Q5. Can we create an instance of an abstract class? Explain your answer.
    No. We can not create an instance of an abstract class. 
    Abstract class is like a template a or blueprint.
    Only inherited sub classes can create instance.
